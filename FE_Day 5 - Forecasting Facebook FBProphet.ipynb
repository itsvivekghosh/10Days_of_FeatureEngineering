# %% [markdown]
# ### Forecasting Timeseries Data Using Facebook FbProphet
#
# #### Steps Required With FbProphet:
#
# - Introduction And Installation
# - Data Preprocessing With Time Seires
# - Model Fitting
# - Obtaining The Forecasts
# - Plotting The Forecasts
# - Cross Validation
# - Computing Performance Metrics
# - Visualize the Performance MEtrics
# - Conclusions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import fbprophet
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
# %matplotlib inline

# %%
df = pd.read_csv("Datasets/monthly-milk-production-pounds.csv")
df.head()
# Out:
#      Month  Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 0  1962-01                                              589.0
# 1  1962-02                                              561.0
# 2  1962-03                                              640.0
# 3  1962-04                                              656.0
# 4  1962-05                                              727.0

# %%
df.shape
# Out:
# (169, 2)

# %%
df.head()
# Out:
#      Month  Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 0  1962-01                                              589.0
# 1  1962-02                                              561.0
# 2  1962-03                                              640.0
# 3  1962-04                                              656.0
# 4  1962-05                                              727.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 164                                            1975-09
# 165                                            1975-10
# 166                                            1975-11
# 167                                            1975-12
# 168  Monthly milk production: pounds per cow. Jan 6...
#
#      Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 164                                              817.0
# 165                                              827.0
# 166                                              797.0
# 167                                              843.0
# 168                                                NaN

# %%
df.drop(168, axis=0, inplace=True)
df.tail()
# Out:
#        Month  Monthly milk production: pounds per cow. Jan 62 ? Dec 75
# 163  1975-08                                              858.0
# 164  1975-09                                              817.0
# 165  1975-10                                              827.0
# 166  1975-11                                              797.0
# 167  1975-12                                              843.0

# %%
df.plot()

# %%
df.columns = ['Date', 'Quantity']
df.head()
# Out:
#       Date  Quantity
# 0  1962-01     589.0
# 1  1962-02     561.0
# 2  1962-03     640.0
# 3  1962-04     656.0
# 4  1962-05     727.0

# %%
df['Date']=pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Quantity
# 0 1962-01-01     589.0
# 1 1962-02-01     561.0
# 2 1962-03-01     640.0
# 3 1962-04-01     656.0
# 4 1962-05-01     727.0

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(df['Date'], df['Quantity'])
plt.xticks(rotation=90)
plt.show()

# %%
df["Quantity"].head(10), df['Quantity'].shift(1).head(10)
# Out:
# (0    589.0
#  1    561.0
#  2    640.0
#  3    656.0
#  4    727.0
#  5    697.0
#  6    640.0
#  7    599.0
#  8    568.0
#  9    577.0
#  Name: Quantity, dtype: float64,
#  0      NaN
#  1    589.0
#  2    561.0
#  3    640.0
#  4    656.0
#  5    727.0
#  6    697.0
#  7    640.0
#  8    599.0
#  9    568.0
#  Name: Quantity, dtype: float64)

# %%
df['Quantity'].shift(1).plot()

# %%
### Shifting to make it stationery
df['Quantity_Stationary'] = df["Quantity"]-df["Quantity"].shift(1)
plt.figure(figsize=(10, 6))
df["Quantity_Stationary"].plot()
plt.show()

# %%
df.head()
# Out:
#         Date  Quantity  Quantity_Stationary
# 0 1962-01-01     589.0                  NaN
# 1 1962-02-01     561.0                -28.0
# 2 1962-03-01     640.0                 79.0
# 3 1962-04-01     656.0                 16.0
# 4 1962-05-01     727.0                 71.0

# %%
from fbprophet import Prophet
dir(Prophet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load_stan_backend',
#  'add_country_holidays',
#  'add_group_component',
#  'add_regressor',
#  'add_seasonality',
#  'construct_holiday_dataframe',
#  'fit',
#  'fourier_series',
#  'initialize_scales',
#  'linear_growth_init',
#  'logistic_growth_init',
#  'make_all_seasonality_features',
#  'make_future_dataframe',
#  'make_holiday_features',
#  'make_seasonality_features',
#  'parse_seasonality_args',
#  'percentile',
#  'piecewise_linear',
#  'piecewise_logistic',
#  'plot',
#  'plot_components',
#  'predict',
#  'predict_seasonal_components',
#  'predict_trend',
#  'predict_uncertainty',
#  'predictive_samples',
#  'regressor_column_matrix',
#  'sample_model',
#  'sample_posterior_predictive',
#  'sample_predictive_trend',
#  'set_auto_seasonalities',
#  'set_changepoints',
#  'setup_dataframe',
#  'validate_column_name',
#  'validate_inputs']

# %%
data = df[['Date', 'Quantity_Stationary']]
data.columns = ['ds', 'y']
data.head()
# Out:
#           ds     y
# 0 1962-01-01   NaN
# 1 1962-02-01 -28.0
# 2 1962-03-01  79.0
# 3 1962-04-01  16.0
# 4 1962-05-01  71.0

# %%
### Initialize the Model
model = Prophet()
model.fit(data)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.seasonalities
# Out:
# OrderedDict([('yearly',
#               {'period': 365.25,
#                'fourier_order': 10,
#                'prior_scale': 10.0,
#                'mode': 'additive',
#                'condition_name': None})])

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
### Create future dates of 365 dates
future_dates = model.make_future_dataframe(periods=365)
future_dates.head()
# Out:
#           ds
# 0 1962-01-01
# 1 1962-02-01
# 2 1962-03-01
# 3 1962-04-01
# 4 1962-05-01

# %%
future_dates.tail()
# Out:
#             ds
# 528 1976-11-26
# 529 1976-11-27
# 530 1976-11-28
# 531 1976-11-29
# 532 1976-11-30

# %% [markdown]
# ####  We have made 365 more days from 1975 and appended to the data

# %%
future_dates.shape
# Out:
# (533, 1)

# %%
### Prediction
prediction=model.predict(future_dates)

# %%
prediction.head()
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1962-01-01  2.039961   17.714146   36.864548     2.039961     2.039961
# 1 1962-02-01  2.038259  -47.843688  -29.328418     2.038259     2.038259
# 2 1962-03-01  2.036721   85.660194  104.881119     2.036721     2.036721
# 3 1962-04-01  2.035019    7.234206   25.109889     2.035019     2.035019
# 4 1962-05-01  2.033371   52.871852   71.752842     2.033371     2.033371
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       24.995850             24.995850             24.995850  24.995850
# 1      -40.254571            -40.254571            -40.254571 -40.254571
# 2       93.020544             93.020544             93.020544  93.020544
# 3       14.324346             14.324346             14.324346  14.324346
# 4       60.541099             60.541099             60.541099  60.541099
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0     24.995850     24.995850                   0.0
# 1    -40.254571    -40.254571                   0.0
# 2     93.020544     93.020544                   0.0
# 3     14.324346     14.324346                   0.0
# 4     60.541099     60.541099                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                         0.0                         0.0  27.035811
# 1                         0.0                         0.0 -38.216312
# 2                         0.0                         0.0  95.057265
# 3                         0.0                         0.0  16.359364
# 4                         0.0                         0.0  62.574470

# %%
prediction[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 528 1976-11-26  12.837593    3.309922   22.142356
# 529 1976-11-27  18.284245    8.381576   28.097153
# 530 1976-11-28  23.863742   14.770463   32.939295
# 531 1976-11-29  29.463572   20.217626   39.164483
# 532 1976-11-30  34.965354   25.254697   44.333108

# %%
3.746558+21.943516/2
# Out:
# 14.718316

# %%
(9.379478+27.786856)/2
# Out:
# 18.583167

# %%
prediction[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 1962-01-01  27.035811   17.714146   36.864548
# 1 1962-02-01 -38.216312  -47.843688  -29.328418
# 2 1962-03-01  95.057265   85.660194  104.881119
# 3 1962-04-01  16.359364    7.234206   25.109889
# 4 1962-05-01  62.574470   52.871852   71.752842

# %% [markdown]
# ### Plotting the Forecasts
#
# Prophet has an inbuilt feature that enables us to plot the forecasts we just generated. This is achieved using model.plot() and passing in our forecasts as the argument. The blue line in the graph represents the predicted values while the black dots represents the data in our dataset.

# %%
#### plot the predicted projection
model.plot(prediction)

# %%
##### Visualize Each Components[Trends, Weekly]
model.plot_components(prediction)

# %% [markdown]
# ### Cross Validation:
#
# Next let’s measure the forecast error using the historical data. We’ll do this by comparing the predicted values with the actual values. In order to perform this operation we select cut of points in the history of the data and fit the model with data upto that cut off point. Afterwards we compare the actual values to the predicted values. The cross_validation method allows us to do this in Prophet. This method take the following parameters as explained below:
#
# - horizon the forecast horizon
# - initial the size of the initial training period
# - period the spacing between cutoff dates

# %%
from fbprophet.diagnostics import cross_validation

# %%
df_cv = cross_validation(
    model,
    horizon="365 days",
    period='180 days',
    initial='1095 days'
)
# Out:
# INFO:fbprophet:Making 20 forecasts with cutoffs between 1965-07-21 00:00:00 and 1974-12-01 00:00:00

# %%
df.head()
# Out:
#         Date  Quantity  Quantity_Stationary
# 0 1962-01-01     589.0                  NaN
# 1 1962-02-01     561.0                -28.0
# 2 1962-03-01     640.0                 79.0
# 3 1962-04-01     656.0                 16.0
# 4 1962-05-01     727.0                 71.0

# %%
df_cv.head()
# Out:
#           ds       yhat  yhat_lower  yhat_upper     y     cutoff
# 0 1965-08-01 -40.898372  -46.305045  -35.861464 -49.0 1965-07-21
# 1 1965-09-01 -34.869323  -40.792294  -29.306445 -38.0 1965-07-21
# 2 1965-10-01   6.103171    0.368846   11.255775   6.0 1965-07-21
# 3 1965-11-01 -20.281526  -25.585081  -14.792195 -19.0 1965-07-21
# 4 1965-12-01  36.035431   30.342558   41.733626  33.0 1965-07-21

# %% [markdown]
# #### Obtaining the Performance Metrics
#
# We use the performance_metrics utility to compute the Mean Squared Error(MSE), Root Mean Squared Error(RMSE),Mean Absolute Error(MAE), Mean Absolute Percentage Error(MAPE) and the coverage of the the yhat_lower and yhat_upper estimates.

# %%
from fbprophet.diagnostics import performance_metrics
df_performance=performance_metrics(df_cv)
df_performance.head()
# Out:
#   horizon         mse       rmse       mae      mape     mdape  coverage
# 0 41 days  123.584092  11.116838  9.150617  0.263083  0.196871  0.500000
# 1 42 days  115.490860  10.746667  8.606019  0.233431  0.177038  0.583333
# 2 43 days  123.835809  11.128154  8.853209  0.227125  0.177038  0.583333
# 3 46 days   89.936969   9.483510  7.912417  0.214467  0.177038  0.625000
# 4 47 days   87.912235   9.376152  7.726750  0.211312  0.177038  0.645833

# %%
from fbprophet.plot import plot_cross_validation_metric
fig=plot_cross_validation_metric(df_cv,metric='rmse')
