# %% [markdown]
# ## Feature Selection Techniques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
# %matplotlib inline

# %%
df = pd.read_csv("Datasets/mobile_dataset.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ### Univariate Selection

# %%
### Univariate Selection
X = df.iloc[:, :-1]
y = df['price_range']
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
### Applying K-Best Algorithm
best_features = SelectKBest(score_func=chi2, k=20)
best_features
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x000001F20B914168>)

# %%
features = best_features.fit(X, y)
features
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x000001F20B914168>)

# %%
df_scores = pd.DataFrame(features.scores_, columns=['Score'])
best_features = pd.concat([pd.DataFrame(X.columns), df_scores], axis=1)
best_features.columns=["Features", "Score"]
best_features = best_features.sort_values(by='Score', ascending=False)
best_features
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878
# 10             pc       9.186054
# 9         n_cores       9.097556
# 18   touch_screen       1.928429
# 5          four_g       1.521572
# 7           m_dep       0.745820
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 19           wifi       0.422091
# 17        three_g       0.327643

# %%
best_features.nlargest(10, "Score")
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ### Feature Importance
# This technique gives you a score for each feature of your data,the higher the score mor relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
model.feature_importances_
# Out:
# array([0.06132195, 0.020282  , 0.03271903, 0.0188976 , 0.03201344,
#        0.0170151 , 0.03556245, 0.03294032, 0.0361209 , 0.03246022,
#        0.03330699, 0.04801391, 0.04889404, 0.3968904 , 0.03281183,
#        0.03391818, 0.03397413, 0.01430428, 0.01875925, 0.019794  ])

# %%
rank_features = pd.Series(model.feature_importances_, index=X.columns)
rank_features.nlargest(10).plot(kind='bar')
plt.show()

# %% [markdown]
# ### Pearson Correlation or Correlation

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
corr = df.corr()
top_features = corr.index
plt.figure(figsize=(20, 20))
sns.heatmap(df[top_features].corr(), annot=True)
plt.show()

# %%
THRESHOLD = 0.5
def correlation(data):
    col_corr = set()
    corr_matrix = data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) >= THRESHOLD:
                col_name = corr_matrix.columns[i]
                col_corr.add(col_name)
    return col_corr

# %%
correlation(df.iloc[:, :-1])

# %% [markdown]
# ### Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info=mutual_info_classif(X, y)

# %%
mutual_data=pd.Series(mutual_info,index = X.columns)
mutual_data.sort_values(ascending = False)
